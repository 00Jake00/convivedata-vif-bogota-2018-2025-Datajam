# %% [markdown]
# # ConviveData · Ejecución reproducible desde GitHub
#
# Este notebook descarga el script reproducible desde el repositorio, carga las fuentes desde `data/raw/` usando GitHub Raw y exporta los resultados en `data/processed/` y `outputs_limpieza/`.

# %% [markdown]
# ## 1. Instalar dependencias
# En Google Colab normalmente solo hace falta asegurar `openpyxl` y `scipy`.

# %%
# !pip -q install pandas numpy scipy openpyxl

# %% [markdown]
# ## 2. Descargar y ejecutar script reproducible
# El script busca primero archivos locales y, si no existen, los descarga desde GitHub Raw.

# %%
import urllib.request
SCRIPT_URL = 'https://raw.githubusercontent.com/00Jake00/convivedata-vif-bogota-2018-2025-Datajam/main/scripts/pruebas_estadisticas_datos_puros_datajam.py'
urllib.request.urlretrieve(SCRIPT_URL, 'pruebas_estadisticas_datos_puros_datajam.py')
print('Script descargado:', SCRIPT_URL)

# %%
# !python pruebas_estadisticas_datos_puros_datajam.py

# %% [markdown]
# ## 3. Revisar resultados

# %%
import pandas as pd
resultados = pd.read_csv('data/processed/resultados_pruebas_estadisticas.csv')
resultados
